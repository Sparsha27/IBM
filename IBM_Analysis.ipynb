# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv('IBM_ridhi.csv')

# %%
a.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
a.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
a.dtypes
# Out:
# Age                         int64
# Attrition                  object
# BusinessTravel             object
# DailyRate                   int64
# Department                 object
# Education                   int64
# EducationField             object
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                     object
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                    object
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# MonthlyRate                 int64
# Over18                     object
# OverTime                   object
# PercentSalaryHike           int64
# PerformanceRating           int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# ...

# %%
a.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
a.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
a.drop('NumCompaniesWorked', inplace=True, axis=1)

# %%
a.drop('RelationshipSatisfaction', inplace=True, axis=1)

# %%
a.drop('StandardHours', inplace=True, axis=1)

# %%
a.drop('DistanceFromHome', inplace=True, axis=1)

# %% [markdown]
# Mathematical Functional Values

# %%
a.describe()
# Out:
#                Age    DailyRate    Education  EmployeeCount  EmployeeNumber  \
# count  1470.000000  1470.000000  1470.000000         1470.0     1470.000000
# mean     36.923810   802.485714     2.912925            1.0     1024.865306
# std       9.135373   403.509100     1.024165            0.0      602.024335
# min      18.000000   102.000000     1.000000            1.0        1.000000
# 25%      30.000000   465.000000     2.000000            1.0      491.250000
# 50%      36.000000   802.000000     3.000000            1.0     1020.500000
# 75%      43.000000  1157.000000     4.000000            1.0     1555.750000
# max      60.000000  1499.000000     5.000000            1.0     2068.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %%
a['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
a['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
a['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
a[a['Department']=='Research & Development'].head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
# 5          2  Life Sciences              1               8
#
#    EnvironmentSatisfaction  ... PercentSalaryHike  PerformanceRating  \
# 1                        3  ...                23                  4
# ...

# %%
a[a['Department']=='Sales'].head()
# Out:
#     Age Attrition BusinessTravel  DailyRate Department  Education  \
# 0    41       Yes  Travel_Rarely       1102      Sales          2
# 18   53        No  Travel_Rarely       1219      Sales          4
# 21   36       Yes  Travel_Rarely       1218      Sales          4
# 27   42        No  Travel_Rarely        691      Sales          4
# 29   46        No  Travel_Rarely        705      Sales          4
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0   Life Sciences              1               1                        2
# 18  Life Sciences              1              23                        1
# 21  Life Sciences              1              27                        3
# 27      Marketing              1              35                        3
# 29      Marketing              1              38                        2
#
#     ... PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# ...

# %%
a[a['Department']=='Human Resources'].head()
# Out:
#      Age Attrition BusinessTravel  DailyRate       Department  Education  \
# 79    46        No  Travel_Rarely        945  Human Resources          2
# 100   37       Yes  Travel_Rarely        807  Human Resources          4
# 105   59        No     Non-Travel       1420  Human Resources          4
# 112   54        No     Non-Travel        142  Human Resources          3
# 134   26        No  Travel_Rarely       1355  Human Resources          1
#
#       EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 79           Medical              1             103                        2
# 100  Human Resources              1             133                        3
# 105  Human Resources              1             140                        3
# 112  Human Resources              1             148                        4
# 134    Life Sciences              1             177                        3
#
# ...

# %%
a.corr()
# Out:
#                               Age  DailyRate  Education  EmployeeCount  \
# Age                      1.000000   0.010661   0.208034            NaN
# DailyRate                0.010661   1.000000  -0.016806            NaN
# Education                0.208034  -0.016806   1.000000            NaN
# EmployeeCount                 NaN        NaN        NaN            NaN
# EmployeeNumber          -0.010145  -0.050990   0.042070            NaN
# EnvironmentSatisfaction  0.010146   0.018355  -0.027128            NaN
# HourlyRate               0.024287   0.023381   0.016775            NaN
# JobInvolvement           0.029820   0.046135   0.042438            NaN
# JobLevel                 0.509604   0.002966   0.101589            NaN
# JobSatisfaction         -0.004892   0.030571  -0.011296            NaN
# MonthlyIncome            0.497855   0.007707   0.094961            NaN
# MonthlyRate              0.028051  -0.032182  -0.026084            NaN
# ...

# %%
a[['JobSatisfaction','JobInvolvement','PerformanceRating','WorkLifeBalance']].corr()
# Out:
#                    JobSatisfaction  JobInvolvement  PerformanceRating  \
# JobSatisfaction           1.000000       -0.021476           0.002297
# JobInvolvement           -0.021476        1.000000          -0.029071
# PerformanceRating         0.002297       -0.029071           1.000000
# WorkLifeBalance          -0.019459       -0.014617           0.002572
#
#                    WorkLifeBalance
# JobSatisfaction          -0.019459
# JobInvolvement           -0.014617
# PerformanceRating         0.002572
# WorkLifeBalance           1.000000

# %%
sns.heatmap(a[['JobSatisfaction','JobInvolvement','PerformanceRating','WorkLifeBalance']].corr())
# Out:
# <AxesSubplot:>
